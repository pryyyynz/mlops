# %% [markdown]
# Q1. Install MLflow

# %%
pip install mlflow
# Out:
# Requirement already satisfied: mlflow in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (2.17.2)
# Requirement already satisfied: mlflow-skinny==2.17.2 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow) (2.17.2)
# Requirement already satisfied: Flask<4 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow) (3.0.3)
# Requirement already satisfied: alembic!=1.10.0,<2 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow) (1.14.0)
# Requirement already satisfied: docker<8,>=4.0.0 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow) (3.4.1)
# Requirement already satisfied: markdown<4,>=3.3 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow) (3.7)
# Requirement already satisfied: matplotlib<4 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow) (3.9.2)
# Requirement already satisfied: numpy<3 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow) (1.26.4)
# Requirement already satisfied: pandas<3 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow) (2.2.3)
# Requirement already satisfied: pyarrow<18,>=4.0.0 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow) (17.0.0)
# Requirement already satisfied: scikit-learn<2 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow) (1.5.2)
# Requirement already satisfied: scipy<2 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow) (1.13.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow) (2.0.36)
# Requirement already satisfied: Jinja2<4,>=2.11 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow) (3.1.4)
# Requirement already satisfied: gunicorn<24 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow) (23.0.0)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow-skinny==2.17.2->mlflow) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow-skinny==2.17.2->mlflow) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow-skinny==2.17.2->mlflow) (3.1.0)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow-skinny==2.17.2->mlflow) (0.36.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow-skinny==2.17.2->mlflow) (3.1.43)
# Requirement already satisfied: importlib-metadata!=4.7.0,<9,>=3.7.0 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow-skinny==2.17.2->mlflow) (8.5.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow-skinny==2.17.2->mlflow) (1.28.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow-skinny==2.17.2->mlflow) (1.28.0)
# Requirement already satisfied: packaging<25 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow-skinny==2.17.2->mlflow) (24.1)
# Requirement already satisfied: protobuf<6,>=3.12.0 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow-skinny==2.17.2->mlflow) (5.28.3)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow-skinny==2.17.2->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow-skinny==2.17.2->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from mlflow-skinny==2.17.2->mlflow) (0.5.1)
# Requirement already satisfied: Mako in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.6)
# Requirement already satisfied: typing-extensions>=4 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from alembic!=1.10.0,<2->mlflow) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from docker<8,>=4.0.0->mlflow) (2.2.3)
# Requirement already satisfied: Werkzeug>=3.0.0 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from Flask<4->mlflow) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from Flask<4->mlflow) (1.8.2)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from graphene<4->mlflow) (3.2.5)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from Jinja2<4,>=2.11->mlflow) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from matplotlib<4->mlflow) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from matplotlib<4->mlflow) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from matplotlib<4->mlflow) (1.4.7)
# Requirement already satisfied: pillow>=8 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from matplotlib<4->mlflow) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from matplotlib<4->mlflow) (3.2.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from matplotlib<4->mlflow) (6.4.5)
# Requirement already satisfied: pytz>=2020.1 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from pandas<3->mlflow) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from pandas<3->mlflow) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from scikit-learn<2->mlflow) (3.5.0)
# Requirement already satisfied: google-auth~=2.0 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.2->mlflow) (2.35.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.17.2->mlflow) (4.0.11)
# Requirement already satisfied: zipp>=3.20 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from importlib-metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.17.2->mlflow) (3.20.2)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.17.2->mlflow) (1.2.14)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.49b0 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.17.2->mlflow) (0.49b0)
# Requirement already satisfied: six>=1.5 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.2->mlflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.2->mlflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.2->mlflow) (2024.8.30)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.17.2->mlflow) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.17.2->mlflow) (5.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.2->mlflow) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.2->mlflow) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.2->mlflow) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mlflow
# Out:
# /Users/macbook/Projects/mlops-1/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# Q2. Download and preprocess the data
#
# We'll use the Green Taxi Trip Records dataset to predict the duration of each trip.
#
# Download the data for January, February and March 2023 in parquet format from here.
#
# Use the script preprocess_data.py located in the folder homework to preprocess the data.

# %% [markdown]
# How many files were saved to OUTPUT_FOLDER?

# %% [markdown]
# 4 files.

# %% [markdown]
# Q3. Train a model with autolog
#
# Your task is to modify the script to enable autologging with MLflow, execute the script and then launch the MLflow UI to check that the experiment run was properly tracked.

# %% [markdown]
# What is the value of the min_samples_split parameter:

# %% [markdown]
# 2

# %% [markdown]
# Q4. Launch the tracking server locally
#
# Your task is to:
#
# launch the tracking server on your local machine,
# select a SQLite db for the backend store and a folder called artifacts for the artifacts store.
# You should keep the tracking server running to work on the next two exercises that use the server.

# %% [markdown]
# In addition to backend-store-uri, what else do you need to pass to properly configure the server?

# %% [markdown]
# --backend-store-uri
# --default-artifact-root

# %% [markdown]
# Q5. Tune model hyperparameters
#
#
# Your task is to modify the script hpo.py and make sure that the validation RMSE is logged to the tracking server for each run of the hyperparameter optimization (you will need to add a few lines of code to the objective function) and run the script without passing any parameters.
#
# After that, open UI and explore the runs from the experiment called random-forest-hyperopt to answer the question below.

# %% [markdown]
# What's the best validation RMSE that you got?

# %% [markdown]
# 5.335

# %% [markdown]
# Q6. Promote the best model to the model registry
#
# Your task is to update the script register_model.py so that it selects the model with the lowest RMSE on the test set and registers it to the model registry.

# %% [markdown]
# What is the test RMSE of the best model?

# %% [markdown]
# 5.567
